# %% [markdown]
# # To download tweets using twitter APi

# %%
"""import tweepy
import csv #Import csv
auth = tweepy.auth.OAuthHandler('xxxxxxxxx', 'xxxxxxxxxxxx')
auth.set_access_token('xxxxxxxxxx', 'xxxxxxxxxxxx')

api = tweepy.API(auth,wait_on_rate_limit=True)

# Open/create a file to append data to
csvFile = open('dataset.csv', 'a',encoding="utf-8",newline='')

#Use csv writer
csvWriter = csv.writer(csvFile)

for tweet in tweepy.Cursor(api.search,count=100000,
                           q = "Covid-19",re.sub('[^a-zA-Z]', '',clean )
                           tweet_mode='extended',
                           lang = "en").items():

    # Write a row to the CSV file. I use encode UTF-8
    csvWriter.writerow([tweet.full_text,tweet.user.screen_name,tweet.user.location])
    print(tweet.full_text,tweet.user.screen_name,tweet.user.location)
csvFile.close()"""
# Out:
# 'import tweepy\nimport csv #Import csv\nauth = tweepy.auth.OAuthHandler(\'xxxxxxxxx\', \'xxxxxxxxxxxx\')\nauth.set_access_token(\'xxxxxxxxxx\', \'xxxxxxxxxxxx\')\n\napi = tweepy.API(auth,wait_on_rate_limit=True)\n\n# Open/create a file to append data to\ncsvFile = open(\'dataset.csv\', \'a\',encoding="utf-8",newline=\'\')\n\n#Use csv writer\ncsvWriter = csv.writer(csvFile)\n\nfor tweet in tweepy.Cursor(api.search,count=100000,\n                           q = "Covid-19",re.sub(\'[^a-zA-Z]\', \'\',clean )\n                           tweet_mode=\'extended\',\n                           lang = "en").items():\n\n    # Write a row to the CSV file. I use encode UTF-8\n    csvWriter.writerow([tweet.full_text,tweet.user.screen_name,tweet.user.location])\n    print(tweet.full_text,tweet.user.screen_name,tweet.user.location)\ncsvFile.close()'

# %% [markdown]
# # Importing dataset and Analysis

# %%
import pandas as pd
file_name='dataset (1).csv'
data = pd.read_csv(file_name, sep = ',',names = ['text','username','location'])
data.shape
# Out:
# (131563, 3)

# %%
data.head()
# Out:
#                                                 text         username  \
# 0  RT @tsum_africa: In response to the current #C...      PaulABarter
# 1  RT @FemAdesina: No presidential broadcast on C...  Abdulazizmento2
# 2  Covid-19 Outbreak in Nigeria Is Just One of Af...   Ricardo_Gardel
# 3  RT @ChangeOrg_India: Walking miles without foo...     ahumanenough
# 4  RT @GhulamABilour: I have been tested positive...      tormakhay_s
#
#            location
# 0         Singapore
# 1     port Harcourt
# 2  Tinton Falls, NJ
# 3               NaN
# 4        Sexi, Peru

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 131563 entries, 0 to 131562
# Data columns (total 3 columns):
# text        131563 non-null object
# username    131563 non-null object
# location    92721 non-null object
# dtypes: object(3)
# memory usage: 3.0+ MB

# %%
data=data[(data['location'].notnull())]                      #dropping empty row
data = data.sample(frac=1).reset_index(drop=True)           #resetting index
data['len']=data["text"].str.len()                          #removing clipped tweets
df1= data[(data['len'] <=137)]
df2=data[(data['len'] >=150)]
data=pd.concat([df1,df2])                              
data = data.sample(frac=1).reset_index(drop=True)       #resetting index

# %%
data.shape
# Out:
# (35482, 4)

# %%
data.head()
# Out:
#                                                 text      username  \
# 0  RT @SkyNewsBreak: Celtic have been declared ch...   Bungle90815
# 1  COVID-19 tracker provides the number of confir...      genes2me
# 2  RT @DilanTheVillain: i can hear the DJs now “i...     kofiscalm
# 3  Office installs UV filtration for added COVID-...   NEheadlines
# 4  Madagascar Bills Nigeria N78.2m For COVID-19 H...  Tori_Nigeria
#
#              location  len
# 0  Sheffield, England  125
# 1      Gurgaon, India  294
# 2           ldn/herts   93
# 3    Hardin County KY  100
# 4      Lagos, Nigeria   82

# %% [markdown]
# # Cleaning data set by removing RT ,Links and @username

# %%
import numpy as np
import re
def remove_pattern(input_txt, pattern):                                           #function to remove pattern 
    r = re.findall(pattern, input_txt)
    for i in r:
        input_txt = re.sub(i, '', input_txt)        
    return input_txt
def clean_tweets(lst):
    lst = np.vectorize(remove_pattern)(lst, "\r")                                  
    lst = np.vectorize(remove_pattern)(lst, "\n")
    lst = np.vectorize(remove_pattern)(lst, "RT @[\w]*:")                         # removing RT @x from tweets:
    lst = np.vectorize(remove_pattern)(lst, "@[\w]*")                             # removing  @xxx from tweets 
    lst = np.vectorize(remove_pattern)(lst, "https?://[A-Za-z0-9./]*")            # reremoving URL links http://xxx
    return lst

# %%
data['clean']= clean_tweets(data['text'])   #Cleaned Tweets are kept in separate coloumn

# %%
data.head()
# Out:
#                                                 text      username  \
# 0  RT @SkyNewsBreak: Celtic have been declared ch...   Bungle90815
# 1  COVID-19 tracker provides the number of confir...      genes2me
# 2  RT @DilanTheVillain: i can hear the DJs now “i...     kofiscalm
# 3  Office installs UV filtration for added COVID-...   NEheadlines
# 4  Madagascar Bills Nigeria N78.2m For COVID-19 H...  Tori_Nigeria
#
#              location  len                                              clean
# 0  Sheffield, England  125   Celtic have been declared champions as the Sc...
# 1      Gurgaon, India  294  COVID-19 tracker provides the number of confir...
# 2           ldn/herts   93   i can hear the DJs now “if you survived COVID...
# 3    Hardin County KY  100  Office installs UV filtration for added COVID-...
# 4      Lagos, Nigeria   82  Madagascar Bills Nigeria N78.2m For COVID-19 H...

# %% [markdown]
# # Function to label tweets based on their sentiment.

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer           #vaderSentiment is used to tag tweets as positive, negative or neutral
analyser = SentimentIntensityAnalyzer()
def sentiment_analyzer_scores(text):
    score = analyser.polarity_scores(text)
    if score['compound'] >= 0.05 :
        return 2
    elif (score['compound'] > -0.05) and (score['compound'] < 0.05) : 
        return 1 
    else :
        return 0

# %%
sentiments_using_vader = data.clean.apply(lambda text: sentiment_analyzer_scores(text))     #Each tweet goes throug vader function and gets labeled.
pd.DataFrame(sentiments_using_vader.value_counts())
# Out:
#    clean
# 2  15621
# 0  10361
# 1   9500

# %%
data['sentiment'] = sentiments_using_vader
data.head()
# Out:
#                                                 text      username  \
# 0  RT @SkyNewsBreak: Celtic have been declared ch...   Bungle90815
# 1  COVID-19 tracker provides the number of confir...      genes2me
# 2  RT @DilanTheVillain: i can hear the DJs now “i...     kofiscalm
# 3  Office installs UV filtration for added COVID-...   NEheadlines
# 4  Madagascar Bills Nigeria N78.2m For COVID-19 H...  Tori_Nigeria
#
#              location  len                                              clean  \
# 0  Sheffield, England  125   Celtic have been declared champions as the Sc...
# 1      Gurgaon, India  294  COVID-19 tracker provides the number of confir...
# 2           ldn/herts   93   i can hear the DJs now “if you survived COVID...
# 3    Hardin County KY  100  Office installs UV filtration for added COVID-...
# 4      Lagos, Nigeria   82  Madagascar Bills Nigeria N78.2m For COVID-19 H...
#
#    sentiment
# 0          2
# 1          2
# 2          2
# 3          1
# 4          1

# %%
data.describe()
# Out:
#                 len     sentiment
# count  35482.000000  35482.000000
# mean     162.006961      1.148244
# std       77.083169      0.842794
# min        8.000000      0.000000
# 25%       98.000000      0.000000
# 50%      129.000000      1.000000
# 75%      233.000000      2.000000
# max      832.000000      2.000000

# %% [markdown]
# # Removing special characters, numbers, punctuations (except for #)

# %%
# remove special characters, numbers, punctuations (except for #)
data['clean'] = data['clean'].str.replace("[^a-zA-Z# ]", "")

# %% [markdown]
# # Removing stopwords ,converting into lower case and applying lematization.

# %%
from nltk.stem import WordNetLemmatizer
wl = WordNetLemmatizer()
from nltk.corpus import stopwords
cleaned_tweets = []
for index, row in data.iterrows():            #This loop goes through every tweets and removes stopwords covnverts into lower case and applyes lematization
    words_without_stopwords = [wl.lemmatize(word.lower()) for word in row.clean.split() if not word in set(stopwords.words('english')) and '#' not in word.lower()]
    cleaned_tweets.append(' '.join(words_without_stopwords))
data['Fully_cleaned_tweets'] = cleaned_tweets
data.head(10)
# Out:
#                                                 text        username  \
# 0  RT @SkyNewsBreak: Celtic have been declared ch...     Bungle90815
# 1  COVID-19 tracker provides the number of confir...        genes2me
# 2  RT @DilanTheVillain: i can hear the DJs now “i...       kofiscalm
# 3  Office installs UV filtration for added COVID-...     NEheadlines
# 4  Madagascar Bills Nigeria N78.2m For COVID-19 H...    Tori_Nigeria
# 5  RT @JohnWar01549456: @Yoyo73Jktech Hey apparen...    Yoyo73Jktech
# 6  gates gave the house of representatives for th...  Benny_is_a_boy
# 7  RT @techreview: Here’s how to safely ease soci...      RaviKapoor
# 8  RT @DilanTheVillain: i can hear the DJs now “i...   goshsoorandom
# 9  My latest post. I couldn't shut up any longer....     steveseager
#
#                          location  len  \
# 0              Sheffield, England  125
# 1                  Gurgaon, India  294
# 2                       ldn/herts   93
# 3                Hardin County KY  100
# 4                  Lagos, Nigeria   82
# 5                United kingdom🇬🇧  125
# 6  Somewhere close to your heart   253
# 7                New Delhi, India  129
# 8      ÜT: -26.2692833,27.9985314   93
# 9      Amsterdam, The Netherlands  155
#
#                                                clean  sentiment  \
# 0   Celtic have been declared champions as the Sc...          2
# 1  COVID tracker provides the number of confirmed...          2
# 2   i can hear the DJs now if you survived COVID ...          2
# 3  Office installs UV filtration for added COVID ...          1
# 4  Madagascar Bills Nigeria Nm For COVID Herbal R...          1
# 5    Hey apparently theyre the next  big thing Jo...          1
# 6  gates gave the house of representatives for th...          0
# 7   Heres how to safely ease social distancing wh...          2
# 8   i can hear the DJs now if you survived COVID ...          2
# 9  My latest post I couldnt shut up any longer A ...          2
#
#                                 Fully_cleaned_tweets
# 0  celtic declared champion scottish premier leag...
# 1  covid tracker provides number confirmed case d...
# 2              hear dj survived covid make mfn noise
# 3  office installs uv filtration added covid prev...
# 4  madagascar bill nigeria nm for covid herbal re...
# 5      hey apparently theyre next big thing jo covid
# 6  gate gave house representative vaccination nig...
# 7  here safely ease social distancing wait covid ...
# 8              hear dj survived covid make mfn noise
# 9  my latest post i couldnt shut longer a kind i ...

# %% [markdown]
# # Bargraph of Sentiment

# %%
import seaborn as sns
sents =[]
for tw in data.Fully_cleaned_tweets:
    st = sentiment_analyzer_scores(tw)
    sents.append(st)
ax = sns.distplot(sents,kde=False,bins=3)
ax.set(xlabel='Negative              Neutral               Positive',ylabel='#Tweets',title="Tweets of USA-corona")
# Out:
# [Text(0, 0.5, '#Tweets'),
#  Text(0.5, 0, 'Negative              Neutral               Positive'),
#  Text(0.5, 1.0, 'Tweets of USA-corona')]

# %% [markdown]
# # Emotion of the tweets

# %%
from collections import Counter

def con(sentence):
    emotion_list = []
    sentence = sentence.split(' ')
    with open('emotions.txt','r') as file:
        for line in file:
            clear_line = line.replace("\n", '').replace(",",'').replace("'",'').strip()
            word, emotion = clear_line.split(':')

            if word in sentence:
                emotion_list.append(emotion)
        w = Counter(emotion_list)
        return w

# %%
data['emotion'] = data['Fully_cleaned_tweets'].apply(lambda x: con(x) )

# %%
data.head(10)
# Out:
#                                                 text        username  \
# 0  RT @SkyNewsBreak: Celtic have been declared ch...     Bungle90815
# 1  COVID-19 tracker provides the number of confir...        genes2me
# 2  RT @DilanTheVillain: i can hear the DJs now “i...       kofiscalm
# 3  Office installs UV filtration for added COVID-...     NEheadlines
# 4  Madagascar Bills Nigeria N78.2m For COVID-19 H...    Tori_Nigeria
# 5  RT @JohnWar01549456: @Yoyo73Jktech Hey apparen...    Yoyo73Jktech
# 6  gates gave the house of representatives for th...  Benny_is_a_boy
# 7  RT @techreview: Here’s how to safely ease soci...      RaviKapoor
# 8  RT @DilanTheVillain: i can hear the DJs now “i...   goshsoorandom
# 9  My latest post. I couldn't shut up any longer....     steveseager
#
#                          location  len  \
# 0              Sheffield, England  125
# 1                  Gurgaon, India  294
# 2                       ldn/herts   93
# 3                Hardin County KY  100
# 4                  Lagos, Nigeria   82
# 5                United kingdom🇬🇧  125
# 6  Somewhere close to your heart   253
# 7                New Delhi, India  129
# 8      ÜT: -26.2692833,27.9985314   93
# 9      Amsterdam, The Netherlands  155
#
#                                                clean  sentiment  \
# 0   Celtic have been declared champions as the Sc...          2
# 1  COVID tracker provides the number of confirmed...          2
# 2   i can hear the DJs now if you survived COVID ...          2
# 3  Office installs UV filtration for added COVID ...          1
# 4  Madagascar Bills Nigeria Nm For COVID Herbal R...          1
# 5    Hey apparently theyre the next  big thing Jo...          1
# 6  gates gave the house of representatives for th...          0
# 7   Heres how to safely ease social distancing wh...          2
# 8   i can hear the DJs now if you survived COVID ...          2
# 9  My latest post I couldnt shut up any longer A ...          2
#
#                                 Fully_cleaned_tweets       emotion
# 0  celtic declared champion scottish premier leag...            {}
# 1  covid tracker provides number confirmed case d...  {' free': 1}
# 2              hear dj survived covid make mfn noise            {}
# 3  office installs uv filtration added covid prev...            {}
# 4  madagascar bill nigeria nm for covid herbal re...            {}
# 5      hey apparently theyre next big thing jo covid            {}
# 6  gate gave house representative vaccination nig...            {}
# 7  here safely ease social distancing wait covid ...            {}
# 8              hear dj survived covid make mfn noise            {}
# 9  my latest post i couldnt shut longer a kind i ...            {}

# %%
emo=con(data['Fully_cleaned_tweets'].sum())

# %%
data['text'][8]
# Out:
# 'RT @DilanTheVillain: i can hear the DJs now “if you survived COVID-19 make some mf’n noise!”😂'

# %% [markdown]
# # Plotting emotion bar graph

# %%
import matplotlib.pyplot as plt
plt.figure(figsize = (15,10))
plt.bar(emo.keys(),emo.values())
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# # Wordcloud

# %%
from PIL import Image
from wordcloud import WordCloud,ImageColorGenerator
import urllib
import requests
import matplotlib.pyplot as plt
def generate_wordcloud(all_words):
    Mask = np.array(Image.open(requests.get('http://clipart-library.com/image_gallery2/Twitter-PNG-Image.png', stream=True).raw))
    image_colors = ImageColorGenerator(Mask)
    wc = WordCloud(background_color='black', height=750, width=2000,mask=Mask).generate(all_words)
    plt.figure(figsize=(10,20))
    plt.imshow(wc.recolor(color_func=image_colors),interpolation="hamming")
    plt.axis('off')
    plt.show()

# %% [markdown]
# # Wordcloud for Positive Sentiment

# %%
all_words = ' '.join([text for text in data['Fully_cleaned_tweets'][data.sentiment == 2]])
generate_wordcloud(all_words)

# %% [markdown]
# # Wordcloud for Neutral Sentiment

# %%
all_words = ' '.join([text for text in data['clean'][data.sentiment == 1]])
generate_wordcloud(all_words)

# %% [markdown]
# # Wordcloud for Negative Sentiment

# %%
all_words = ' '.join([text for text in data['clean'][data.sentiment == 0]])
generate_wordcloud(all_words)

# %% [markdown]
# # Creating Hastag FreqDist

# %%
import nltk
                                                  #function to collect hashtags
def hashtag_extract(text_list):
    hashtags = []
    # Loop over the words in the tweet
    for text in text_list:
        ht = re.findall(r"#(\w+)", text)
        hashtags.append(ht)

    return hashtags

def generate_hashtag_freqdist(hashtags):
    a = nltk.FreqDist(hashtags)
    d = pd.DataFrame({'Hashtag': list(a.keys()),
                      'Count': list(a.values())})
    # selecting top 15 most frequent hashtags     
    d = d.nlargest(columns="Count", n = 25)
    plt.figure(figsize=(16,7))
    ax = sns.barplot(data=d, x= "Hashtag", y = "Count")
    plt.xticks(rotation=80)
    ax.set(ylabel = 'Count')
    plt.show()

# %%
hashtags = hashtag_extract(data['clean'])
hashtags = sum(hashtags, [])

# %%
generate_hashtag_freqdist(hashtags)

# %% [markdown]
# # Tweets location bargraph

# %%
data['location'].value_counts().head(30).plot(kind='barh', figsize=(6,10))

# %% [markdown]
# # Extracting X and y from dataset

# %%
x = data.iloc[:,-2].values
y = data.iloc[:,-3].values

# %% [markdown]
# # Creating tfid vectorizer model

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
tfidf_word_vectorizer = TfidfVectorizer(max_df=0.90, min_df=2, stop_words='english')
x = tfidf_word_vectorizer.fit_transform(x)

# %% [markdown]
# # Creating training and test data from the featureset and output label.

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2)

# %% [markdown]
# #  Create and training a Machine Learning model.

# %%
from sklearn.ensemble import RandomForestClassifier
classifier = RandomForestClassifier()
classifier.fit(X_train, y_train)
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %% [markdown]
# # Validate the model created.

# %%
predictions = classifier.predict(X_test.toarray())

# %% [markdown]
# # Predicting sentiment of manual input

# %%
file_name='TestTweet.csv'
test=pd.read_csv(file_name)

# %%
test['clean']=clean_tweets(test['text']) 
test['clean']=test['clean'].str.replace("[^a-zA-Z ]", " ")

# %%
for i,tweet in enumerate(test['clean']):
    op=classifier.predict(tfidf_word_vectorizer.transform([tweet]).toarray())
    if op == [0]:
        print(i,")"," ' ",test.text[i]," ' ",'\n','=','NEGATIVE','\n')
    if op == [1]:
        print(i,")"," ' ",test.text[i]," ' ",'\n','=','NEUTRAL','\n')
    if op == [2]:
        print(i,")"," ' ",test.text[i]," ' ",'\n','=','POSITIVE','\n')
# Out:
# 0 )  '  RT @djnicholl: Show us proof that Johnson is following science, MPs urge
#
# https://t.co/aN9ofVaQBV  '
#  = NEUTRAL
#
# 1 )  '  Why people think 5G responsible for coronavirus https://t.co/jloVJuO0G0 via @YouTube  '
#  = NEUTRAL
#
# 2 )  '  Yesterday I was walking along a pier of the #Amsterdam Oude Houthaven when an angry houseboat resident invited me leave as "they don't like walkers due to the #coronavirus" WTF...  '
#  = POSITIVE
#
# 3 )  '  RT @WyeLea: The coronavirus crisis must not be allowed to delay Brexit https://t.co/4n6mip2MVg  '
#  = NEGATIVE
#
# 4 )  '  #N4P #C4XD #IQAI
# Coronavirus: Moderna’s US vaccine first trials show immune response https://t.co/2vy25EMqEY  '
#  = POSITIVE
#
# 5 )  '  @HeshmatAlavi China knew what they were doing as soon as President Trump signed those papers. China will fulfill their deal as long as no pandemic happens. TWO days later &amp; here is Coronavirus knocking at our doors! Sue them, I say.  '
#  = NEGATIVE
#
# 6 )  '  RT @jonworth: Even by Brexit standards, England’s handling of its Coronavirus response is inept  '
#  = NEUTRAL
#
# 7 )  '  RT @ClimateReality: 'We’re running out of time to flatten the curve — for climate change'
# https://t.co/9bUJzYygKZ  '
#  = POSITIVE
#
# 8 )  '  HSE encourages ‘social bubble’ https://t.co/0oIkLBSzi7  '
#  = NEUTRAL
#
# 9 )  '  RT @BBCScotlandNews: Four residents die at an Aberdeenshire care home after contracting #coronavirus
# https://t.co/Jrk4d4a2uq  '
#  = NEGATIVE
#
# 10 )  '  We have begun the dreaded third quarter of isolation, when — yes — things get weird https://t.co/rv0R2sO9z1  '
#  = POSITIVE
#
# 11 )  '  RT @fatnerdsloveme: the coronavirus wipes out all the men in the valley...just a thought  '
#  = NEUTRAL
#
# 12 )  '  RT @BBCScotlandNews: Four residents die at an Aberdeenshire care home after contracting #coronavirus
# https://t.co/Jrk4d4a2uq  '
#  = NEGATIVE
#
# 13 )  '  RT @LisaBaumann: BREAKING (AP): Judge tosses out Oregon's coronavirus restrictions  '
#  = NEUTRAL
#
# 14 )  '  RT @prempanicker: @Aaabshar Yeah I saw this, thanks. Was my point actually. No one ever saw these:
#
# https://t.co/1jwattFFP2  '
#  = POSITIVE
#
# 15 )  '  RT @AJENews: Top tennis stars pitch in for Pakistan coronavirus relief efforts https://t.co/lvWG1oVXvj https://t.co/BwBm11lgeO  '
#  = POSITIVE
#
# 16 )  '  RT @Pumpkinz16: No government could have been completely ready for the pandemic, but taking the public for fools has destroyed all trust…  '
#  = POSITIVE
#
# 17 )  '  RT @washingtonpost: Opinion: Trump is using the coronavirus as a cover to abuse his authority https://t.co/BM331nIelg  '
#  = NEGATIVE
#
# 18 )  '  Plotting stringency of measures and confirmed COVID-19 cases per capita (10.000) clearly shows the difference between countries
# https://t.co/A4AdS35P53
# https://t.co/6JTZPDYnPt https://t.co/V6EL6qba6h  '
#  = NEUTRAL
#
# 19 )  '  RT @CRTejada: Poor Countries Borrowed Billions from China. They Can’t Pay It Back. https://t.co/PE9ryLqYqn  '
#  = NEGATIVE
#
# 20 )  '  @politicalmath Right you are. If Ohio had been as creative with its numbers as georgia, pulling dates out of sequence so it could show a downward trend of Coronaviruses, it too could be a model! https://t.co/yQyDxQeBOb https://t.co/BhHU9U6bIj  '
#  = NEUTRAL
#
# 21 )  '  RT @Independent: Ricky Gervais wants celebrities banned from New Year’s Honours list in favour of NHS workers https://t.co/Pl8ZGqWtzX  '
#  = NEUTRAL
#
# 22 )  '  Meeting up with people might spread the virus. Total shocker🤪
# https://t.co/Bm6eIDYDva  '
#  = NEUTRAL
#
# 23 )  '  The Salvation Army is rattling the can online, determined to reinvent its biggest fundraiser for the year, amid isolation. | @TiffWarne #coronavirus #COVID19 https://t.co/xwdlEvwHVD  '
#  = NEGATIVE
#
# 24 )  '  @jack_sommers @lorraine @jack_sommers just watching you on @Lorraine on ITV1 and want to send you lots of good luck and love. Here's hoping all goes well for you with the vaccine tests and that you keep well and safe #coronavirus #covid19UK #brave #CourageisBeautiful #BlessYourHeart #Goodluck  '
#  = POSITIVE
#
# 25 )  '  New Zealand adopts interesting compromise for coronavirus location-tracking https://t.co/Rkordc9giT via @benlovejoy  '
#  = POSITIVE
#
# 26 )  '  RT @RoseUnwin: Coronavirus tests denied to people with learning disabilities despite 175% rise in their deaths https://t.co/cMf0fR082n  '
#  = NEUTRAL
#
# 27 )  '  If this is treu about #coronavirus
# ...very very scary! Or fake?
#
# https://t.co/BfecHoaa79  '
#  = NEUTRAL
#
# 28 )  '  Maybe frozen wood frogs is the cure for this coronavirus https://t.co/7Kz15PhKqY  '
#  = NEUTRAL
#
# 29 )  '  India: overtakes China .. is new coronavirus epicentre in Asia Pacific • lockdown failing reportedly due to unscientific implementation | May 19 2020 https://t.co/Hx2zlTiOwi https://t.co/QoP2gVXBvb  '
#  = NEUTRAL
#
# 30 )  '  Why I’m ready to start traveling again soon https://t.co/YAOo3A6fhb  '
#  = POSITIVE
#
# 31 )  '  An experimental coronavirus vaccine will go into production at a  “rapid deployment facility” before clinical trials have established whether the vaccines are safe &amp; protect against the infection https://t.co/UbfERlvFZt
# It would allow manufacture to begin “at scale” this summer  '
#  = POSITIVE
#
# 32 )  '  Employers will be able to make their claims through a new online service from May 26
# https://t.co/fjZB64YMIR https://t.co/H6Cafdft8h  '
#  = NEUTRAL
#
# 33 )  '  @SabraLane @msbfitzgerald Why didn't your report on China's barley tariff penalty explore Morrison's anti-China rhetoric as the likely cause? Morrison has sacrificed our national interest to support Trump's re-election strategy - https://t.co/a3SpngfHcJ #auspol  '
#  = POSITIVE
#
# 34 )  '  RT @ZeeNewsEnglish: From 100 to 100,000, it took 64 days for coronavirus COVID-19 to touch 1 lakh mark in India
# https://t.co/VXmaAeKK9E  '
#  = NEUTRAL
#
# 35 )  '  The Philippine private sector has so far accounted for 66% of the coronavirus testing capacity of the country.
#
# Meanwhile, the government accounted for only 34% of the total tests conducted.
#
# Data from Coronavirus Plan Deputy Chief Implementor Vivencio Dizon, as of May 14 2020. https://t.co/djYznPJ3Uw  '
#  = NEUTRAL
#
# 36 )  '  @NixZielinski @DC_Draino That's probably a symptom of coronavirus:)  '
#  = NEUTRAL
#
# 37 )  '  Just got my coffee ☕️ stock, in case there is a second coronavirus 🦠 wave and lockdown coming. Are 6 packages 📦 per row enough? 😅😇 #coffee #corona #lockdown #coffeelover #coffeeaddict #coronavirus #lockdown2020… https://t.co/4ptJHAQk9c  '
#  = NEUTRAL
#
# 38 )  '  Living rooms across the country are now experimental design studios - IKEA designs forts for children in lockdown https://t.co/WXjwNMvLHU  '
#  = NEUTRAL
#
# 39 )  '  RT @Daily_Record: Claims rose by 856,000 in the first month of #coronavirus lockdown
#
# https://t.co/KeEt5dcCne  '
#  = NEUTRAL
#
# 40 )  '  And, it is worth repeating, children do not pose any greater infection risk than other people. -Coronavirus: Irish performance midtable at best in international terms by ⁦@paulcullenit⁩
# via @IrishTimes
# https://t.co/82IG5UCWyf  '
#  = POSITIVE
#
# 41 )  '  RT @TrailMagazine: The latest advice for hillwalkers regarding coronavirus restrictions from @Team_BMC https://t.co/hefRAcxGBf  '
#  = NEUTRAL
#
# 42 )  '  There's been a breakthrough in the race to create a COVID-19 vaccine. A US company has conducted the first successful human trial. It's provided a glimmer of hope for a world desperate to end the pandemic. https://t.co/AVvaWLotVs @AmeliaBrace #7NEWS https://t.co/AN1qUlzMED  '
#  = POSITIVE
#
# 43 )  '  The company has signed deals with Swiss contract drugmaker Lonza Group AG and the US government to produce massive quantities of its vaccine.
# https://t.co/RV7byI3DIJ  '
#  = POSITIVE
#
# 44 )  '  This is what classrooms could look like if schools reopen next month https://t.co/PLwQ2qMzDd  '
#  = POSITIVE
#
# 45 )  '  #SADCYOUTH Coronavirus Update
#
# The COVID19 cases continue to rise&amp;do you know the symptoms of #COVID19?
# ●Sore throat
# ●Dry cough
# ●Fever
# ●Shortness of breath
# If you have these symptoms or are feeling unwell, please inform your Health authorities: Read: https://t.co/e4lycAMBR4 https://t.co/Zzx5BkT8z3  '
#  = NEUTRAL
#
# 46 )  '  RT @lilianeden: @davidicke Hi David, this is interesting  https://t.co/KneBWyLGr5  '
#  = POSITIVE
#
# 47 )  '  The latest on the coronavirus outbreak with Bobby @bobbyisawake &amp; Stacy @Livviesmomma -
# ✅DeWine: Bar owners could lose their liquor licenses if they don’t control their customers
# ✅Experimental vaccine shows encouraging results
# ✅Trump taking hydroxychloroquine https://t.co/rAhIv5Wmki  '
#  = NEGATIVE
#
# 48 )  '  RT @RealJamesWoods: And if not, CNN will do everything it can to get us there...  https://t.co/tXG0u7XFKO  '
#  = NEUTRAL
# 49 )  '  @WyeLea Agreed 100% Let's face it, we are already in a situation of a severe downturn due to the Coronavirus. The remainer argument about supply chains won't matter as we are already badly affected (for now). So we may as leave as things cannot get any worse, only much better.  '
#  = POSITIVE
#
# 50 )  '  RT @EaterSouls: 72 people test positive for coronavirus after mass lockdown protest in Wisconsin https://t.co/CDzqAt6aAw  '
#  = POSITIVE
#
# 51 )  '  Joining @SeneddCWLC is Nick Capaldi, Chief Executive @Arts_Wales_. Giving evidence on behalf of the sector, and discussing the support available for people and organisations working in the arts during the coronavirus crisis. https://t.co/YMPGpcgJWY  '
#  = POSITIVE
#
# 52 )  '  US #coronavirus death toll surpasses 90,000
# #WamNews
# https://t.co/O8RjoaMRyp https://t.co/5ykXRixOa8  '
#  = NEGATIVE
#
# 53 )  '  RT @washingtonpost: Opinion: Trump is using the coronavirus as a cover to abuse his authority https://t.co/BM331nIelg  '
#  = NEGATIVE
#
# 54 )  '  One restaurant in New Jersey is turning back the clock and transforming into an old-style carhop from the 1950s and 60s amid the coronavirus. https://t.co/PgsO05h19D  '
#  = NEUTRAL
#
# 55 )  '  RT @nickybligh: What a great initiative for young actors.  https://t.co/9dNPVLgVza  '
#  = POSITIVE
#
# 56 )  '  BBC News - Coronavirus: When did care homes go into lockdown? https://t.co/p71bwkfZ1W  '
#  = POSITIVE
#
# 57 )  '  @GordonGChang @TheresaAFallon @POTUS #coronavirus China gave its backing to an investigation into the origins of the coronavirus but insisted on it being carried out by the World Health Organisation, setting up a clash with the United States, which has lost patience with the body? ¥ Bribery!!!! https://t.co/6sPqKk2XH8  '
#  = NEUTRAL
#
# 58 )  '  RT @msnuk: France sees flare-up of 70 new coronavirus cases after schools reopen https://t.co/091RbRGvXZ  '
#  = NEUTRAL
#
# 59 )  '  Our Spring Job Fair is now being held online because of coronavirus but there are still lots of great roles available in Tameside.
#
# To attend the Virtual Job Fair head to the link below where you can find lots of new vacancies 👇
#
# https://t.co/xDfVK4mhxW https://t.co/vZs9hC2Sqd  '
#  = POSITIVE
#
# 60 )  '  New lows in Humanity in Bharat circa 2020 https://t.co/k4ybxj040P  '
#  = NEUTRAL
#
# 61 )  '  AP PHOTOS: Medical students get a first-hand look at medical history being made as they help out a Greek hospital designated as a key coronavirus treatment center. https://t.co/eF9LjYhXbf  '
#  = POSITIVE
#
# 62 )  '  We did see a aircraft show already. Didn't we?
# #Modi #FrontLineHeroes #healthcare #Doctors #COVID19India #Covid_19 #coronavirus https://t.co/OC5aY6njH3  '
#  = NEUTRAL
#
# 63 )  '  RT @Morning_Joe: How coronavirus impacted one healthy, young runner: https://t.co/W7HH8CEwOm --@MaraGay  '
#  = NEUTRAL
#
# 64 )  '  turned out negative. Now I don't know what type of test they did but CDC here says there are two types of test. 1) viral test - current, 2) antibody test - if you had previously.
# https://t.co/uvQsgkVkLk
#
# I'm using this study for the SK protocol-ish https://t.co/CPuAMK4ASs  '
#  = NEGATIVE
#
# 65 )  '  @Ben57825351 @SavantIdiom @batleyell @Nadjdaniela A simple Google brings up plenty of articles but here you go...
# https://t.co/10Vd6F4tYs  '
#  = NEUTRAL
#
# 66 )  '  RT @PeckhamVision: BBC News - Coronavirus: Muslims urged to avoid communal Eid celebrations https://t.co/nEfhr03NgU  '
#  = NEUTRAL
#
# 67 )  '  Our online CPD accredited course ‘Environmental cleaning during the COVID-19 outbreak’ has been receiving five star reviews. Have you taken it yet?
# https://t.co/UG2qtv5oYn
# #coronavirus #Covid_19 #coronavirusuk #Covid19UK https://t.co/xeVPcH8kKz  '
#  = NEUTRAL
#
# 68 )  '  Dr. Francis Boyle Says #Coronavirus is Biological Warfare Weapon https://t.co/Txr7rzvfUM #BiologicalWarfare #BiologicalWeapons #Covid19 #CrimesAgainstHumanity #DrFrancisBoyle #FortDetrick #HumanRights #Video #Wuhan https://t.co/N7cQxOOdv2  '
#  = NEUTRAL
#
# 69 )  '  New guidelines for employers on #workingsafely during #coronavirus cover 8 workplace settings.
#
# Employers may need to use more than one set of guidance to cover different locations.
#
# See the government guidance here: https://t.co/WTUsHXyXYq https://t.co/XF6SRPtSPX  '
#  = NEUTRAL
#
# 70 )  '  RT @fayedsouza: Really well put by @arundhatikatju . A must read
#
# https://t.co/ZLgRqJuSbC  '
#  = NEUTRAL
#
# 71 )  '  Tokyo Olympics officials are incensed that their games emblem has been used in the cover design of a local magazine that combines the logo with the novel coronavirus.
# https://t.co/b6dJHFSGKC  '
#  = NEUTRAL
#
# 72 )  '  RT @Kerryactivism: Texas Supreme Court blocks plan to allow mail-in ballots amid coronavirus https://t.co/khTjvitAqC via @nypost  '
#  = NEUTRAL
#
# 73 )  '  RT @SportsCenter: Khabib Nurmagomedov says his father is in critical condition with the coronavirus. https://t.co/UwG6FDtGfx  '
#  = NEUTRAL
#
# 74 )  '  Once again The #UKGovernment will refuse to take advantage and learn from other countries. They have been negligent as it is, but this... this cannot happen here now. How can our young children adhere to #SocialDistancing ? It’s too soon!
#
# https://t.co/a9NsmB5gJi  '
#  = NEUTRAL
#
# 75 )  '  RT @nigella_i5e: EU crumbling: Italexit fears a George Soros admits Italy could follow UK out of bloc..... https://t.co/gZZqabw0Im  '
#  = NEUTRAL
#
# 76 )  '  Was weird hearing Patel going on about how “it’s been four years since the British public voting for independence from the European Union” - Brexit is so passé, we have the coronavirus now  '
#  = NEUTRAL
#
# 77 )  '  RT @Jordan9ja: #Jib : Experts Predict U.S #Coronavirus Outbreak Could Be Over By July: https://t.co/wnNpZjFrU1  '
#  = NEUTRAL
#
# 78 )  '  @Officialneha @Officialneha They didn't know what kind of circumstances that can lead this to #coronavirus #ZeroSocialDistancing #PoorManagement #WorseSituation #SpreadAwareness
#
# Things can be handled in better way if certain measures are taken preplanned.  '
#  = POSITIVE
#
# 79 )  '  RT @PatC63316307: France sees 70 coronavirus cases linked to schools days after reopening https://t.co/2Z2aVKl0Lx  '
#  = NEUTRAL
#
# 80 )  '  'I'm just glad we're able to do something for them': Capital High School seniors honored as the Class of COVID-19 https://t.co/F3Cr1K1cJ6  '
#  = NEUTRAL
#
# 81 )  '  Russia reports 9,263 new cases of coronavirus and 115 new deaths over the past 24 hours, raising the total to 299,941 cases and 2,837 dead. There are 7,352,316 patients tested in the country so far.  '
#  = NEGATIVE
#
# 82 )  '  RT @Nux_Taku: I hope Coronavirus pulls a "No Game No Life" and never gets a sequel  '
#  = POSITIVE
#
# 83 )  '  RT @Pun_Starr: I think BJP leaders should most beware of Zee News journalists. Coronavirus can be transferred through boot licking.  '
#  = NEUTRAL
#
# 84 )  '  RT @liltxhurricane4: Coronavirus aid for undocumented immigrants in California kicks off on May 18 https://t.co/FTRdHr9aOa via @nbcnews  '
#  = NEUTRAL
#
# 85 )  '  Antibody that inhibits the new coronavirus discovered in patient who had SARS 17 years ago https://t.co/OD56ugBYbP  '
#  = NEUTRAL
#
# 86 )  '  RT @JoyceWhiteVance: Follow the money https://t.co/inYdnUGOt2  '
#  = NEUTRAL
#
# 87 )  '  Powerful testimony - Dr Jane Goodall on Coronavirus_ We Brought This on Ourselves https://t.co/USLayKbDdS #extinctionrebellion #climatechange #wetmarkets #bushmeat  '
#  = NEUTRAL
#
# 88 )  '  The UK Government Coronavirus briefing lineup should Level 5 ever be reached. https://t.co/A9RfwKZsgZ  '
#  = NEUTRAL
#
# 89 )  '  @jack_sommers @lorraine Total selflessness and very courageous sir...I applaud you 👏 #coronavirus #vaccine #Covid_19 #Thankyou #Hope  '
#  = POSITIVE
#
# 90 )  '  RT @JohnWest_JAWS: Unbelievable
#
# https://t.co/VShsxseeQy  '
#  = NEUTRAL
#
# 91 )  '  Health and care worker COVID-19 testing available across mid and south Essex. For more information please visit: https://t.co/PWNPt1eYq8  #COVID19 #Coronavirus https://t.co/aMWnpvlmTH  '
#  = POSITIVE
#
# 92 )  '  Important news for small and medium-sized businesses in Lincolnshire here. https://t.co/SbcLOxdN1f  '
#  = POSITIVE
#
# 93 )  '  Why people think #5G responsible for #coronavirus https://t.co/jloVJuO0G0 via @YouTube  '
#  = NEUTRAL
#
# 94 )  '  RT @voiceoftheEast: Five Fresh Cases Of Coronavirus Confirmed In Abia State https://t.co/U6DS4gubmw https://t.co/YWEPJkpZZZ  '
#  = NEUTRAL
#
# 95 )  '  NEW: The Government issues an updated response to a Parliamentary petition to say they “cannot safely include” a BSL interpreter in the room for their daily coronavirus briefings “without potentially putting them and others at risk”. #WhereIsTheInterpreter
# https://t.co/eC3zbS6vJ7  '
#  = NEGATIVE
#
# 96 )  '  RT @nousha_mohd: Zee News: Noida's most deadly coronavirus hotspot.@ZeeNews
#
# #ZeeNewsSealKaro https://t.co/jzi3RbqIQy  '
#  = NEUTRAL
#
# 97 )  '  @DrHilaryJones If people who receive the vaccine are not exposed to Coronavirus how do we know how well it works &amp; whether the vaccine makes the symptoms worse..? Thank you  '
#  = POSITIVE
#
# 98 )  '  #Uber to cut 3,000 more jobs as #coronavirus crisis rises
#
# #layoffs #Jobs #lockdown #COVID19
#
# https://t.co/2tX3WUZxSo  '
#  = NEGATIVE
#
# 99 )  '  Cannabis extracts may help to prevent coronavirus, study suggests https://t.co/8kCRJXEIez #CannabisNews #Cannabis  '
#  = POSITIVE
#
# 100 )  '  During these uncertain times, many of us will be worried about how we manage our rent 🏠
#
# We are here to help you
# Talk to us 💬
#
# The following organisations have guidance on how Coronavirus may affect income &amp; benefits ⬇️
#
# 🟡 @DWP
# 🟠 @CitizensAdvice
# 🟢 @YourMoneyAdvice https://t.co/VRhGlbZT4n  '
#  = POSITIVE
#
# 101 )  '  The Government has issued an update on the symptoms of coronavirus - see below. https://t.co/TkkWJgwP1q  '
#  = NEUTRAL
#
# 102 )  '  RT @Partisangirl: Just realise that outside of the US #Hydroxycloroquine is not a controversial drug. https://t.co/mYg3Y3Hw9E  '
#  = NEUTRAL
#
# 103 )  '  RT @Peston: Why didn't the government protect us earlier from coronavirus? https://t.co/RslSSTYnvp  '
#  = POSITIVE
# 104 )  '  @lisamurkowski Imagine the difference if Trump Republicans spent as much time on coronavirus as they do Obama, Clinton, and China “conspiracies”. And to top it off, they call the coronavirus a hoax and the “conspiracies” all real. Trump Republicans can fool some once, but now it’s your life! https://t.co/roOG3rmTrR  '
#  = NEGATIVE
#
# 105 )  '  Aged-care homes locked down as Australia reaches grim milestone with 100th death | The New Daily https://t.co/BRg9bv0MW3  '
#  = POSITIVE
#
# 106 )  '  An incredibly inspiring video showing all the efforts that goes into saving lives, pushing boundaries and persisting in spite of all challenges. The great sense of mission and fortitude that is required and drives all of us! #inspiration #Covid_19 #coronavirus #PrecisionMedicine https://t.co/w8coAogWS4  '
#  = POSITIVE
#
# 107 )  '  19 new confirmed cases of #COVID19 in the yet-to-be-named firm in Ibadan
#
# Now, this is serious.
#
# My Ibadan people, make una continue to stay safe
#
# #coronavirus  '
#  = POSITIVE
#
# 108 )  '  @MobilePunch This is what he has been preaching to his congregation. One of the member in my area that attends the church has been going around telling people about how 5G and not Coronavirus is responsible for what the world is currently battling at this point.  '
#  = POSITIVE
#
# 109 )  '  https://t.co/DG3hrNNIXF - UK unemployment surges to 1.35 million – expert expects very quick rise to over 10%  '
#  = NEUTRAL
#
# 110 )  '  @hezedgodson @RKRadhakrishn @kv_ramanan @ramyakannan yep, as if they had a telepathy with #coronavirus. d dumbo who said #TamilNadu wud be corona free in 3days n its d disease of d rich is d CM. we stand helpless. we’ve a great duty ahead, we cant simply sit n watch. we #millennials shd form a political movement aiming for CM chair  '
#  = POSITIVE
#
# 111 )  '  RT @washingtonpost: Opinion: Trump is using the coronavirus as a cover to abuse his authority https://t.co/BM331nIelg  '
#  = NEGATIVE
#
# 112 )  '  RT @Peston: Why didn't the government protect us earlier from coronavirus? https://t.co/RslSSTYnvp  '
#  = POSITIVE
#
# 113 )  '  RT @Independent: France sees 70 coronavirus cases linked to schools days after reopening https://t.co/7IjRBagAZw  '
#  = NEUTRAL
#
# 114 )  '  Still sharing #TaiwanModel even though we got no #WHA73 invitation this year. So how does #Taiwan fight #coronavirus? Last but not least, we fight misinformation and issue government announcements. https://t.co/8GYNpBSbHX  '
#  = NEGATIVE
#
# 115 )  '  The jokes are amazing. At one point she mocks Arab politicians and religious leaders comparing the coronavirus to homosexuals by trying to use their logic: Corona means crown and LGBTQs say 'yas Queen!' and Queens wear crowns, therefore they've caused the virus.  '
#  = POSITIVE
#
# 116 )  '  RT @RTPIScotland: 'A new normal': how coronavirus will transform transport in Britain's cities https://t.co/ORwQQUzWLp  '
#  = NEUTRAL
#
# 117 )  '  RT @washingtonpost: Opinion: Trump is using the coronavirus as a cover to abuse his authority https://t.co/BM331nIelg  '
#  = NEGATIVE
#
# 118 )  '  RT @SCIE_socialcare: Thanks to @WrenchKatie for a blog for #MentalHealthAwarenessWeek https://t.co/0kjnFMx6Vz #covid19 #socialcare  '
#  = POSITIVE
#
# 119 )  '  @SenAlexander Imagine the difference if Trump Republicans spent as much time on coronavirus as they do Obama, Clinton, and China “conspiracies”. And to top it off, they call the coronavirus a hoax and the “conspiracies” all real. Trump Republicans can fool some once, but now it’s your life! https://t.co/O1JprYbxt7  '
#  = NEGATIVE
#
# 120 )  '  RT @lovelightGod4u: @shay_tera I am so sorry to hear of this horrific attack! Prayers are on the way.
#
# https://t.co/eIEDQOZH6P  '
#  = NEGATIVE
#
# 121 )  '  Trump is fighting a public health crisis with denial and self-promotion https://t.co/L8FZc93FyG  '
#  = NEGATIVE
#
# 122 )  '  ‘The Coronavirus Op And Mass Mind Programming - David Icke Talks To Jeff Rense’ on #SoundCloud #np https://t.co/vTkVQH6VCd  '
#  = NEUTRAL
#
# 123 )  '  He already got the coronavirus! https://t.co/48JQnMSpgZ  '
#  = NEUTRAL
#
# 124 )  '  Premier League clubs face checks to ensure coronavirus protocols are being observed #afcb https://t.co/602bHFq3WQ  '
#  = POSITIVE
#
# 125 )  '  Zee Media newsroom, studios sealed after 28 employees test positive for coronavirus - https://t.co/7gOMyheWw6  '
#  = POSITIVE
#
# 126 )  '  #CoronavirusUpdates: #COVID19 Cases Rise to 260 as 12 New Infections are Confirmed on Monday
# #ChimpReportsNews  #UgandaNews #Uganda #Featured #Coronavirus
# @MinofHealthUG @UVRIug @GovUganda @ainbyoo #StaySafeUG #Tonsemberera #Masks4All #M7Address #News
# https://t.co/gZOkGKbyyM  '
#  = NEUTRAL
#
# 127 )  '  #Bihar has reported 1,423 confirmed #COVID19 cases, of which 652 are migrant labourers who have returned home from outside the state. Here's more
#
# #Coronavirus #COVIDIndia
#
# https://t.co/3zjhhN68dJ  '
#  = NEUTRAL
#
# 128 )  '  Summer unlikely to curb coronavirus pandemic growth: study https://t.co/PUmB0prqoO https://t.co/nUFdyfIuiy  '
#  = NEUTRAL
#
# 129 )  '  RT @RoseUnwin: Coronavirus tests denied to people with learning disabilities despite 175% rise in their deaths https://t.co/cMf0fR082n  '
#  = NEUTRAL
#
# 130 )  '  RT @TurkishMinuteTM: Turkey’s coronavirus cases exceed 150,000, death toll at 4,171 https://t.co/AQUyWjal8E  '
#  = NEGATIVE
#
# 131 )  '  RT @AngrierWHStaff: Who could have imagined that the states who opened early are now seeing record single-day coronavirus increases? 🤦‍♂️  '
#  = NEUTRAL
#
# 132 )  '  Online events are now common, which can help some autistic people, but video chat may be challenging for others. Text chat can be a useful alternative.
# Researcher and community member, Karen Leneh Buckle shared her experience running text chat meetings.
# https://t.co/VJC2UfBI4T  '
#  = POSITIVE
#
# 133 )  '  Coronavirus Florida: Public meetings to resume for Town of Palm Beach https://t.co/Lqmj09QSAm  '
#  = NEUTRAL
#
# 134 )  '  RT @etherealpogues: coronavirus can't kill me because i died when i watched this scene
# #OuterBanks
#  https://t.co/MbWzFbRkrv  '
#  = NEGATIVE
#
# 135 )  '  Virtual parliament was a complete success, so of course it must be ended at once | Tom Peck https://t.co/WOJfJxpIIg  '
#  = POSITIVE
#
# 136 )  '  RT @97thmonkey: Workplace safety inspections promised by Boris Johnson 'don't exist' https://t.co/BEAbLv1gkP  '
#  = POSITIVE
#
# 137 )  '  RT @washingtonpost: Opinion: Trump is using the coronavirus as a cover to abuse his authority https://t.co/BM331nIelg  '
#  = NEGATIVE
#
# 138 )  '  @CGTNOfficial #Hubei measures the culture and traavel industry #coronavirus 🇨🇳  '
#  = NEUTRAL
#
# 139 )  '  International #airtravel is starting to creep back, complete with patchy network of destinations, virus tests and quarantines:
# https://t.co/TwyqU08YC1
# #Aviation #Airlines #Airports #COVID19 #Coronavirus  '
#  = NEUTRAL
#
# 140 )  '  Trump says that he has been taking #hydroxychloroquine, an antimalarial drug the #FDA warned could cause serious heart problems for coronavirus patients. He is taking the drug as a preventive measure and continued to test negative for the #coronavirus. https://t.co/8r9m9uYYXh  '
#  = NEGATIVE
#
# 141 )  '  Brilliant video. Happily #Finland hasn't skated across thin ice without due attention to the cracks in its #coronavirus strategy https://t.co/4D5iqZfQCZ  '
#  = NEUTRAL
#
# 142 )  '  Wow there's a lot of rich people caring about poor people all of a sudden...
#
# Almost as if they want us to go back to work because they're seeing their wealth dissipate.
#
# #lockdown2020 #coronavirus #Covid19UK  '
#  = POSITIVE
#
# 143 )  '  Commentary: Past pandemics changed the design of cities. Six ways COVID-19 could do the same https://t.co/EdJWLMXdtB  '
#  = NEUTRAL
#
# 144 )  '  RT @MiamiHerald: Florida’s COVID-19 website guru blasts bosses, hints at data suppression. https://t.co/16sva7VeW0  '
#  = NEUTRAL
#
# 145 )  '  Australia and China spat over coronavirus inquiry deepens https://t.co/2dfTxGdWWE  '
#  = NEUTRAL
#
# 146 )  '  China stole a patent from a US company conducting trials in Wuhan the early days of the outbreak. China/CCP spread the virus, they should be liable for damages. Not only free vaccines, but more.
#
# (I doubt China's vaccines will work tho lol)
#
# https://t.co/Gcxyw3kC1O  '
#  = POSITIVE
#
# 147 )  '  BMJ damns UK government for mishandling coronavirus outbreak and ignoring science.
# Too damn late now, the damage has been done and the human cost is high.
#
# https://t.co/HKnPHrN6uW  '
#  = NEGATIVE
#
# 148 )  '  RT @Pun_Starr: I think BJP leaders should most beware of Zee News journalists. Coronavirus can be transferred through boot licking.  '
#  = NEUTRAL
#
# 149 )  '  @suchetadalal @DeepikaBhardwaj This confirms that Mahindra has made Ambu Bags. https://t.co/DrJx4LphVE  '
#  = NEUTRAL
#
# 150 )  '  Trump threatens to keep WHO funding freeze in place after White House probe on early coronavirus failures https://t.co/tv37xsLtE4 #FoxNews #CNN #MSNBC  '
#  = NEGATIVE
#
# 151 )  '  #Democrats have a plan for the #coronavirus that was started in the #UnitedStates in 2019 with #Republicans in control. #JoeBiden is the answer.
# #TrumpTrialForCoronavirusDeaths
#
# #NancyPelosiAmericanHero https://t.co/fCvREjKzVj  '
#  = NEUTRAL
#
# 152 )  '  #Oregon coronavirus restrictions kept in place, for now - May 19 @ 4:15 AM ET https://t.co/Pv8sry0tR1  '
#  = NEUTRAL
#
# 153 )  '  Saturday Sunshine Drenched Beltzville Park
# Friday was the first day coronavirus lockdown orders were lifted at Beltzville State Park in Carbon County, 54 miles north of Sanatoga. By Saturday, plenty of people were enjoying sunny time there.
# https://t.co/fUDunSAyCl https://t.co/DjQoTFguiJ  '
#  = POSITIVE
#
# 154 )  '  RT @wellbeingvenues: How has lockdown changed Yoga?
#
# https://t.co/R0rgINZmYF
#
# #yoga #coronavirus #onlineyoga  '
#  = NEUTRAL
#
# 155 )  '  RT @Isabel21294528: @CGTNOfficial #Hubei measures the culture and traavel industry #coronavirus 🇨🇳  '
#  = NEUTRAL
#
# 156 )  '  @Ericyip77316500 Past vaccines took many more years to develop.
# According to scientists, SARS-CoV-2, like other coronavirus, doesn't mutate as much. But, doctors found it dangerous and intractable. It can attack anywhere in the body w. devastating consequences.  '
#  = POSITIVE
#
# 157 )  '  "The pandemic has taught us the importance of preparation"
#
# "Perhaps the upheaval of #COVID19 can inspire us to take much-needed preventive action for the #climate, biosphere &amp; humanity"
#
# —@KaiChanUBC, @IPBES #GlobalAssessment lead author
# via @globalnews
#
# https://t.co/CbtlUF8GJd  '
#  = POSITIVE
#
# 158 )  '  RT @alanmaddison20: After opening from the11th May, a reported 69 french schools have now closed after detecting Coronavirus infections.  '
#  = NEUTRAL
# 159 )  '  Moderna's #coronavirus vaccine candidate is starting to show the first signs of an immune response of the same level as natural infection.
#
# https://t.co/66z3ZXdvWm  '
#  = POSITIVE
#
# 160 )  '  How Kickstarter Creators Are Coping with the Coronavirus — Kickstarter CRYPTO CRYPTO NEWS - https://t.co/dyibqUd8lp  '
#  = NEUTRAL
#
# 161 )  '  https://t.co/N98sqEULg2
# Finally watched #ChernobylHBO one word: #brilliant.  Reminds me of how #Trump &amp; other governments’ handling of the #coronavirus is similar to Chernobyl’s. Discrediting scientists, spinning lies &amp; misinformation for the sole purpose of staying in power.  '
#  = NEGATIVE
#
# 162 )  '  Private firms working for the public good in coronavirus outbreak https://t.co/YyQPKQZqb7  '
#  = POSITIVE
#
# 163 )  '  RT @ProfBambra: The Sage advice must be published now to find where Britain got coronavirus wrong https://t.co/Z2aKbEgmCt  '
#  = NEUTRAL
#
# 164 )  '  The organisers of Great Yarmouth’s largest #summer #festivals are announcing the unavoidable cancellation of their #events this year, to help protect public health and safety in response to the continued #coronavirus threat. #StayAlert #ControlTheVirus #SaveLives https://t.co/nIMwaulM6Q  '
#  = POSITIVE
#
# 165 )  '  RT @Peston: Why didn't Boris act sooner against coronavirus? | The Spectator https://t.co/nNpSR8JxTj  '
#  = NEUTRAL
#
# 166 )  '  Hmmm...
# California churchgoer tests positive for coronavirus one day after service; 180 exposed https://t.co/pKgxIFJOtp via @nbcnews  '
#  = POSITIVE
#
# 167 )  '  RT @brawday: PM lining up civil servants to take blame for coronavirus response https://t.co/G1c2EjIqyn  '
#  = NEGATIVE
#
# 168 )  '  RT @dsue1441_re: Robert De Niro calls trump a "lunatic" who "doesn't care" how many people die from coronavirus https://t.co/LBDu2ujeYF  '
#  = NEGATIVE
#
# 169 )  '  RT @washingtonpost: Opinion: Trump is using the coronavirus as a cover to abuse his authority https://t.co/BM331nIelg  '
#  = NEGATIVE
#
# 170 )  '  RT @piersmorgan: Shameless &amp; shameful. The only thing this Govt threw around care homes was the coronavirus. https://t.co/eDSZyjNGbb  '
#  = POSITIVE
#
# 171 )  '  The latest HUB News Daily! https://t.co/GVEQCoHTIp #coronavirus #sme  '
#  = NEUTRAL
#
# 172 )  '  RT @i_theindian: Zee News: Noida's most deadly coronavirus hotspot.
#
# #ZeeNewsSealKaro https://t.co/EQguBVKH0X  '
#  = NEUTRAL
#
# 173 )  '  RT @Pumpkinz16: No government could have been completely ready for the pandemic, but taking the public for fools has destroyed all trust…  '
#  = POSITIVE
#
# 174 )  '  Amazing research going on 🌿 Come on UK!!
# #broadiessupplements #CBD #coronavirus
# https://t.co/5QAAXhkkBy  '
#  = NEUTRAL
#
# 175 )  '  Why is this not main @BBCNews All they keep banging on about is Denmark which was completely on top of the coronavirus. France have closed 50 schools that reopened after 1 week already https://t.co/LjHojrphIP  '
#  = NEUTRAL
#
# 176 )  '  RT @Q13FOX: Judge rules that Oregon virus restrictions are invalid https://t.co/7EEG1o2Qg5 https://t.co/jqolflHd7n  '
#  = NEUTRAL
#
# 177 )  '  Covid-19 Impact: Canada's Privacy Commissioners Outline Guidance For Governments And Developers Of... https://t.co/OVXG8RTipG  '
#  = NEUTRAL
#
# 178 )  '  RT @fthealth: How coronavirus is exacerbating gaps in school provision https://t.co/2LswylNPJ9  '
#  = NEUTRAL
#
# 179 )  '  For tips and ideas on how to look after your mental health click on the resource pack below:
#
# https://t.co/4yuoCgYwnC  '
#  = NEUTRAL
#
# 180 )  '  @moreelen Time to sacrifice the shower curtain:
# https://t.co/HRiyVXlOzc  '
#  = NEUTRAL
#
# 181 )  '  #LegendsCasino pushes back #reopening to #June7 https://t.co/s1Gz5dEC79 via @Yakima_Herald  '
#  = NEUTRAL
#
# 182 )  '  Australia has reached a grim milestone; our 100th death from coronavirus. 93-year-old Alice Bacon passed away this morning at Sydney's Newmarch House. She is the 19th resident to die and her grieving family says it should not have happened. https://t.co/6iNboeyc4R #7NEWS https://t.co/HsdAQsoJbA  '
#  = NEGATIVE
#
# 183 )  '  @Ilhan Imagine the difference if Trump Republicans spent as much time on coronavirus as they do Obama, Clinton, and China “conspiracies”. And to top it off, they call the coronavirus a hoax and the “conspiracies” all real. Trump Republicans can fool some once, but now it’s your life! https://t.co/1JcJjJvArc  '
#  = NEGATIVE
#
# 184 )  '  #LastWeekinAI -  #AI chatbots gaining traction amid the pandemic, #AIEurovision contest has a winner and more  🔽
# 1. @techreview: https://t.co/fdqrL2OWR5
# 2. @verge: https://t.co/itorCIWGAP
# 3. @BBCWorld: https://t.co/L7wvlIgiSo https://t.co/NCe1PNO9Ow  '
#  = NEUTRAL
#
# 185 )  '  RT @shammybaweja: ‘Robbing the living and the dead of basic dignity’  https://t.co/WW0zXOGCcu  '
#  = NEGATIVE
#
# 186 )  '  Something for everyone.
# “Politics in America: My Offensive views on Abortion, LGBTQ, Sharia Law, 5G, The Death Penalty and…” by Mark Scofield https://t.co/iqljhyRF0j
# #COVID19 #coronavirus #thebadinfluence  '
#  = NEGATIVE
#
# 187 )  '  BBC News - Coronavirus: Delirium 'may be common' in Covid seriously ill https://t.co/p5G3tEX6RA  '
#  = NEUTRAL
#
# 188 )  '  Blanquer did not specify if the 70 cases of COVID-19 were among students or teachers.
# https://t.co/0jPSR4yR9j  '
#  = NEUTRAL
#
# 189 )  '  China’s Unrestricted Warfare Could Lead to Collapse in One Year https://t.co/9BKOrZiF8Y via @YouTube
# #CCPvirus #WakeUpAmerica #ResistTyranny #StandUpToEvil #COVID19 #Coronavirus #NoWorldOrder #SpyState #ContactTracing  '
#  = NEUTRAL
#
# 190 )  '  Phone calls offered to older adults staying home during coronavirus pandemic https://t.co/Kc6xLZaW2h  '
#  = NEUTRAL
#
# 191 )  '  @ai6yrham forced to have implanted microchips by Bill Gates." Change the subject from coronavirus to whatever other subject and you will find people in psych wards across the USA hospitalized for saying very similar things. We call this paranoia and delusions. It is a significant mental  '
#  = NEGATIVE
#
# 192 )  '  As the first tragic images of the UK’s coronavirus victims began to emerge, it quickly became evident the lives being lost were disproportionately those from black, Asian, and minority ethnic (BAME) communities.
#  https://t.co/SHGWxKjAWo  '
#  = NEGATIVE
#
# 193 )  '  .@matthewsyed on effects of groupthink on UK gov Covid-19 planning:
#
# "It is easy for groups to become fixated on one aspect of a fast-changing situation, thereby missing others... A defective judgment is made because..."
#
# 1/2
#  https://t.co/lpMmUhKGtj  '
#  = NEGATIVE
#
# 194 )  '  RT @JoyceWhiteVance: Follow the money https://t.co/inYdnUGOt2  '
#  = NEUTRAL
#
# 195 )  '  ON AIR: ZAMAJOBE / Adding value to lives daily .Talk to us on 0208 90 2121 HELLO@FANTASTICRADIO.CO.UK #FANTASTICRADIOUK #HOMEOFPOSSIBILITIES #BELIEVEYOURPOSSIBILITIES #STAYHOMESAFELIVES https://t.co/bE4hgti6fx
#  Buy song https://t.co/xR9WS7JEu9 https://t.co/TH58a8uAeE  '
#  = POSITIVE
#
# 196 )  '  Coronavirus: Isle of Wight contact-tracing app trial - a mixed verdict so far. That’s what you get when you think you’re superior to leading software companies. #ContactTracingApp #Covid_19  https://t.co/31oluE9h74  '
#  = NEUTRAL
#
# 197 )  '  @TNMilitaryDept Imagine the difference if Trump Republicans spent as much time on coronavirus as they do Obama, Clinton, and China “conspiracies”. And to top it off, they call the coronavirus a hoax and the “conspiracies” all real. Trump Republicans can fool some once, but now it’s your life! https://t.co/PuU0Kw36q5  '
#  = NEGATIVE
#
# 198 )  '  #CayugaNation #reopens its #casino while others in #NewYork remain closed https://t.co/LvK9BBsFpg  '
#  = NEUTRAL
#
# 199 )  '  The UK studies nicotine and the Ooni claims a coronavirus cure on this week’s selection of #covidworldvscovidng https://t.co/GpCHvqdhz9  '
#  = NEUTRAL
#
# 200 )  '  Seeing a report on my local bar in #morbegno reopening made me emotional. Oh to be there with a frozen Bitter Campari or six right now. #coronavirus #valtellina #imback  '
#  = NEUTRAL
#
# 201 )  '  ⁦@jonburkeUK⁩ “It is very important that we democratise these spaces so we need to see these mini-Holland type initiatives in the most deprived areas and more prosperous neighbourhoods … good stuff for everyone must be our mantra.” 👏🏼👏🏼 https://t.co/wH3AubzNlj  '
#  = POSITIVE
#
# 202 )  '  RT @jacquep: US lockdown protests may have spread virus widely, cellphone data suggests https://t.co/ozL4t43x5H  '
#  = NEUTRAL
#
# 203 )  '  RT @AP: Oregon Supreme Court halts judge’s order rescinding state's coronavirus stay-at-home restrictions. https://t.co/H1CjCPX6Ei  '
#  = POSITIVE
#
# 204 )  '  RT @Pun_Starr: I think BJP leaders should most beware of Zee News journalists. Coronavirus can be transferred through boot licking.  '
#  = NEUTRAL
#
# 205 )  '  Second https://t.co/R7Yzduz9J5. Corrections Officer Tests Positive For Coronavirus https://t.co/0JEK8Vksvc  '
#  = POSITIVE
#
# 206 )  '  The Trump Administration Is Rushing Deportations of #Migrants Children During #Coronavirus #COVID19  https://t.co/CABU0Ahlmz  '
#  = NEUTRAL
#
# 207 )  '  ‘The Morrison Govt’s refusal 2 extend JobKeeper 2 unis is having real consequences - regional campuses closing, hundreds of jobs lost. They could fix it with the stroke of a pen’
#
# Staff accept voluntary redundancies as CQU struggles with $116m loss https://t.co/UbgnCuiVky  '
#  = NEGATIVE
#
# 208 )  '  I don't think that 'let them pick spuds' is a particualatly good luck. The nasty party goes back to type here as minister says there are plenty of jobs. https://t.co/X8FOnEpKg1  '
#  = POSITIVE
#
# 209 )  '  "The police, not the coronavirus, killed my son"-father of Mohammad Rizwan, whom policemen allegedly beat up while he was trying to buy food, who died on Saturday.
#
# Link for the full article in the Telegraph India...
#
# https://t.co/QXpHaF0nup
#
# #HumanRights  '
#  = NEGATIVE
#
# 210 )  '  India coronavirus cases surge past 100,000, deaths top 3,000 https://t.co/XfhuqZpbNv  '
#  = NEUTRAL
#
# 211 )  '  “The world’s third-largest economy shrank an annualized 3.4% in the three months through March from the previous quarter as exports slid and social distancing crimped consumer spending..” https://t.co/ekjZkTfx3B  '
#  = NEUTRAL
#
# 212 )  '  #BREAKING: There are now 100 deaths in Australia due to coronavirus.  '
#  = NEUTRAL
# 213 )  '  Include the true value of nature when rebuilding economies after coronavirus https://t.co/KTmmjtHZcg  '
#  = POSITIVE
#
# 214 )  '  Keeping in touch with employees working from home during Coronavirus pandemic is so important for mental health. Provide opportunities for keeping in touch - maintain contact and a team spirit.
# #HR #MentalHealthAwarenessWeek https://t.co/SOdqTuSKoA  '
#  = POSITIVE
#
# 215 )  '  SOMEBODY WAS LISTENING ABOUT #CORONAVIRUS:
#
# 14
# #TuesdayThoughts https://t.co/zrFPxnN0QQ  '
#  = NEUTRAL
#
# 216 )  '  @sheencr Found this useful summary of research conducted and peer reviews on them too https://t.co/O71mYFFa5z  '
#  = POSITIVE
#
# 217 )  '  RT @washingtonpost: Opinion: Trump is using the coronavirus as a cover to abuse his authority https://t.co/BM331nIelg  '
#  = NEGATIVE
#
# 218 )  '  RT @NTynesideNASUWT: Gavin Williamson under fire over free school meal cuts during coronavirus outbreak https://t.co/7vJSNHqsO7  '
#  = POSITIVE
#
# 219 )  '  RT @washingtonpost: Opinion: Trump is using the coronavirus as a cover to abuse his authority https://t.co/BM331nIelg  '
#  = NEGATIVE
#
# 220 )  '  RT @LeVostreGC: Sorrye to share bad newes, but thys ys bad newes. Ther must be some waye to helpe.
# https://t.co/BN843mdMLo  '
#  = POSITIVE
#
# 221 )  '  Do not #self-diagnose . It gives you a false sense of #Security
# #coronavirus https://t.co/eroFAlJddY  '
#  = POSITIVE
#
# 222 )  '  Wolves extend 33-year-old English goalkeeper John Ruddy's contract by a further year. (Birmingham Mail)
#
# Watford's English striker Troy Deeney fear Premier League players will face a public backlash over mass testing for coronavirus. (Good Morning Britain via Evening Standard)  '
#  = POSITIVE
#
# 223 )  '  Coronavirus is actually a gift to mankind, because it has gifted us God. It made us realize God. It has made us realize that there is a power beyond us. A power beyond human comprehension, that governs our destiny. This power is the devine power we call God.
# 1/2  '
#  = POSITIVE
#
# 224 )  '  RT @spectatorindex: JUST IN: Worldwide coronavirus death toll reaches 320,000  '
#  = NEGATIVE
#
# 225 )  '  RT @Bijan63: Brilliant cartoon:
# #Trump gets tested.
# There's nothing there.
# #Coronavirus https://t.co/c6iUjz6EL0  '
#  = NEUTRAL
#
# 226 )  '  @JamesMelville @FreeSpe84593309 Fight Coronavirus before Brexitvirus.  '
#  = NEGATIVE
#
# 227 )  '  RT @smallcappick: #N4P #C4XD #IQAI
# Coronavirus: Moderna’s US vaccine first trials show immune response https://t.co/2vy25EMqEY  '
#  = POSITIVE
#
# 228 )  '  https://t.co/sF7lZQaFjJ
# U know love WE ARE PROUD!
# U KNOW OF WHAT?OF YOU.
# We loved a GOLDEN-HEARTED Man❤
# We kept faith in you that my Dev will change the so called definition of politics! You haters r praising the MP DEV! What do we want more? @idevadhikari ❤Go ahead love❤🙏 https://t.co/U60NCb3Lh9  '
#  = POSITIVE
#
# 229 )  '  What country would accept British holidaymakers when we are rife with Covid19 and no proper testing.
#
# https://t.co/285JQNwkwJ  '
#  = NEUTRAL
#
# 230 )  '  RT @washingtonpost: Opinion: Trump is using the coronavirus as a cover to abuse his authority https://t.co/BM331nIelg  '
#  = NEGATIVE
#
# 231 )  '  SDO Wants COVID 19 Patients Out Of Private Hospitals
#
# Private health establishments in Douala have been given 72 hours to transfer all coronavirus patients in their keeping to health establishments earmarked by government to host COVID-19 patients accross the city.  '
#  = NEUTRAL
#
# 232 )  '  RT @medical_xpress: Coronavirus infections may lead to delirium and potentially PTSD @uclnews @TheLancet https://t.co/oXcLalsaIJ  '
#  = NEUTRAL
#
# 233 )  '  Zee Media newsroom, studios sealed after 28 employees test positive for coronavirus - https://t.co/b6Knph0T1q  '
#  = POSITIVE
#
# 234 )  '  @LizzieStokes1 Hi Lizzie, the latest available information is available here: https://t.co/2MF5bOjtFk. However, we do have a dedicated helpline that will be able to clear this up as the guidance may not that specific. Thanks, Anas  '
#  = POSITIVE
#
# 235 )  '  RT @Jordan9ja: #Jib : Oh No! 3-Day-Old Baby Dies After His Mother Contracted #coronavirus Before His Birth: https://t.co/l8k6RX9dD2  '
#  = NEUTRAL
#
# 236 )  '  UK wrong to rule out global coronavirus comparisons, experts say https://t.co/RpS5cjYAa4  '
#  = NEUTRAL

# %%
tweet="@briantylercohen Hey #Insane @realDonaldTrump ! Are you crazy? ANY of them don't need to die at all."
clean=clean_tweets(tweet)
clean=str(clean)
clean=re.sub('[^a-zA-Z]', ' ',clean )
clean=[clean]
op=classifier.predict(tfidf_word_vectorizer.transform(clean).toarray())
if op == [0]:
    print(tweet,'\n','=','NEGATIVE','\n')
if op == [1]:
    print(tweet,'\n','=','NEUTRAL','\n')
if op == [2]:
    print(tweet,'\n','=','POSITIVE','\n')
# Out:
# @briantylercohen Hey #Insane @realDonaldTrump ! Are you crazy? ANY of them don't need to die at all.
#  = NEGATIVE

# %% [markdown]
# # Evaluate the model

# %%
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
print('Accuracy score : ',accuracy_score(y_test, predictions)*100,'\n')
# Out:
# Accuracy score :  83.52825137381993

# %%
print(confusion_matrix(y_test,predictions),'\n')
# Out:
# [[1547  220  296]
#  [  84 1683  162]
#  [ 158  249 2698]]

# %%
print(classification_report(y_test,predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.75      0.80      2063
#            1       0.78      0.87      0.82      1929
#            2       0.85      0.87      0.86      3105
#
#     accuracy                           0.84      7097
#    macro avg       0.83      0.83      0.83      7097
# weighted avg       0.84      0.84      0.83      7097
